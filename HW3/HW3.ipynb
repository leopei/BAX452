# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from ggplot import *
from ggplot import aes

# %%
df = pd.read_excel('crime in CA.xls')

# %%
df
# Out:
#                                                   City  Population  \
# 0                                             Adelanto     31165.0
# 1                                         Agoura Hills     20762.0
# 2                                              Alameda     76206.0
# 3                                               Albany     19104.0
# 4                                             Alhambra     84710.0
# 5                                          Aliso Viejo     50005.0
# 6                                              Alturas      2681.0
# 7                                      American Canyon     20068.0
# 8                                              Anaheim    345320.0
# 9                                             Anderson     10098.0
# 10                                             Antioch    106447.0
# 11                                        Apple Valley     71159.0
# 12                                             Arcadia     57855.0
# ...

# %%
df.isnull().sum()
# Out:
# City                                    0
# Population                              2
# Total crime                             2
# Violent crime                           2
# Murder and nonnegligent manslaughter    2
# Rape (legacy definition)2               2
# Robbery                                 2
# Aggravated assault                      2
# Property crime                          2
# Burglary                                2
# Larceny-theft                           2
# Motor vehicle theft                     2
# Arson                                   2
# dtype: int64

# %%
df_pop200 = df[df['Population'] > 200000]

# %%
df_pop200.dtypes
# Out:
# City                                     object
# Population                              float64
# Total crime                             float64
# Violent crime                           float64
# Murder and nonnegligent manslaughter    float64
# Rape (legacy definition)2               float64
# Robbery                                 float64
# Aggravated assault                      float64
# Property crime                          float64
# Burglary                                float64
# Larceny-theft                           float64
# Motor vehicle theft                     float64
# Arson                                   float64
# dtype: object

# %%
df_pop200
# Out:
#                City  Population  Total crime  Violent crime  \
# 8           Anaheim    345320.0      21517.0         1130.0
# 24      Bakersfield    361859.0      37535.0         1857.0
# 73      Chula Vista    255073.0      11793.0          595.0
# 140         Fontana    203427.0       9635.0          725.0
# 147         Fremont    224475.0       8761.0          273.0
# 148          Fresno    508876.0      50456.0         2552.0
# 190          Irvine    235830.0       6806.0          113.0
# 230      Long Beach    469665.0      30787.0         2346.0
# 234     Los Angeles   3878725.0     206166.0        16524.0
# 255         Modesto    204252.0      23448.0         1704.0
# 265   Moreno Valley    201284.0      13024.0          638.0
# 282         Oakland    403887.0      66460.0         7984.0
# 292          Oxnard    202594.0      11486.0          651.0
# 339       Riverside    316423.0      23951.0         1330.0
# 347      Sacramento    478182.0      42398.0         3137.0
# ...

# %%
df_pop200['Violent Crime Percentage'] = df_pop200['Total crime']/df['Violent crime']
# Out:
# /Users/raehuang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_pop200['Violence'] = np.where(df_pop200['Violent Crime Percentage'] >= 20, 'Yes', 'No')
# Out:
# /Users/raehuang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ggplot(df_pop200 ,aes(x = 'Population' , y = 'Total crime', color = 'City')) + geom_point(size = 100) +\
xlim(175000,550000) + ylim(0,75000)
# Out:
# <ggplot: (-9223372029295396110)>

# %%
ggplot(df_pop200 ,aes(x = 'Population' , y = 'Total crime', color = 'City')) + geom_point(size = 100) +\
xlim(175000,550000) + ylim(0,75000) + facet_grid('Violence')
# Out:
# <ggplot: (7559241059)>

# %%
df_corr = df_pop200.drop(['City','Total crime','Violent Crime Percentage','Violence'], axis=1)

# %%
df_corr
# Out:
#      Population  Violent crime  Murder and nonnegligent manslaughter  \
# 8      345320.0         1130.0                                  11.0
# 24     361859.0         1857.0                                  24.0
# 73     255073.0          595.0                                   2.0
# 140    203427.0          725.0                                  10.0
# 147    224475.0          273.0                                   1.0
# 148    508876.0         2552.0                                  40.0
# 190    235830.0          113.0                                   2.0
# 230    469665.0         2346.0                                  34.0
# 234   3878725.0        16524.0                                 251.0
# 255    204252.0         1704.0                                  14.0
# 265    201284.0          638.0                                  10.0
# 282    403887.0         7984.0                                  90.0
# 292    202594.0          651.0                                  15.0
# ...

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df_corr.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, 
            linecolor='white', annot=True)

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df,test_size=0.2)
train.head()
# Out:
#                 City  Population  Total crime  Violent crime  \
# 121        El Centro     43249.0       4369.0          144.0
# 202     Laguna Hills     31134.0       1123.0           53.0
# 148           Fresno    508876.0      50456.0         2552.0
# 175         Highland     54462.0       3115.0          191.0
# 7    American Canyon     20068.0       1130.0           54.0
#
#      Murder and nonnegligent manslaughter  Rape (legacy definition)2  Robbery  \
# 121                                   1.0                        7.0     54.0
# 202                                   0.0                        3.0     12.0
# 148                                  40.0                       53.0    903.0
# 175                                   3.0                        8.0     56.0
# 7                                     0.0                        4.0     31.0
#
#      Aggravated assault  Property crime  Burglary  Larceny-theft  \
# ...

# %%
test.head()
# Out:
#              City  Population  Total crime  Violent crime  \
# 266   Morgan Hill     39907.0       1480.0           63.0
# 341  Rohnert Park     41326.0       1738.0          180.0
# 56      Calistoga      5223.0        168.0            9.0
# 452       Windsor     27249.0        752.0          105.0
# 438   Watsonville     52076.0       3099.0          237.0
#
#      Murder and nonnegligent manslaughter  Rape (legacy definition)2  Robbery  \
# 266                                   1.0                       11.0     10.0
# 341                                   1.0                       16.0     24.0
# 56                                    0.0                        1.0      1.0
# 452                                   0.0                        9.0      8.0
# 438                                   3.0                       20.0     71.0
#
#      Aggravated assault  Property crime  Burglary  Larceny-theft  \
# 266                41.0           676.0     162.0          416.0
# ...
